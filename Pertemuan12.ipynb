# %% [markdown]
# <a href="https://colab.research.google.com/github/Alerakha/05_Aleron-Tsaqif-Rakha_PCVK_Ganjil_2024/blob/main/Pertemuan12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import Image
import requests
from io import BytesIO
from google.colab import drive
import matplotlib.pyplot as plt
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')
jokowi_ori = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg')
jokowi_copy = jokowi_ori.copy()
roi_wajah = cascade_wajah.detectMultiScale(jokowi_copy)
for (x,y,w,h) in roi_wajah:
  cv2.rectangle(jokowi_copy,(x,y),(x+w,y+h),(0,255,0),2)
plt.figure(figsize = (10,10))
jokowi_ori = cv2.cvtColor(jokowi_ori, cv2.COLOR_BGR2RGB)
jokowi_copy = cv2.cvtColor(jokowi_copy, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(jokowi_ori)
plt.subplot(1,2,2)
plt.imshow(jokowi_copy)
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')
kartini_ori = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/kartini.jpg')
kartini_copy = kartini_ori.copy()
roi_wajah = cascade_wajah.detectMultiScale(kartini_copy)
for (x,y,w,h) in roi_wajah:
  cv2.rectangle(kartini_copy,(x,y),(x+w,y+h),(0,255,0),2)
plt.figure(figsize = (10,10))
kartini_ori = cv2.cvtColor(kartini_ori, cv2.COLOR_BGR2RGB)
kartini_copy = cv2.cvtColor(kartini_copy, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(kartini_ori)
plt.subplot(1,2,2)
plt.imshow(kartini_copy)
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')
kucing_ori = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/kucing.jpg',0)
cat_gray = kucing_ori.copy()
roi_wajah = cascade_wajah.detectMultiScale(cat_gray)
for (x,y,w,h) in roi_wajah:
  cv2.rectangle(cat_gray,(x,y),(x+w,y+h),(0,255,0),2)
plt.figure(figsize = (10,10))
kucing_ori = cv2.cvtColor(kucing_ori, cv2.COLOR_BGR2RGB)
cat_gray = cv2.cvtColor(cat_gray, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(kucing_ori)
plt.subplot(1,2,2)
plt.imshow(cat_gray)
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')
mask = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/mask.png')
mask_copy = mask.copy()
roi_wajah = cascade_wajah.detectMultiScale(mask_copy)
for (x,y,w,h) in roi_wajah:
  cv2.rectangle(mask_copy,(x,y),(x+w,y+h),(0,255,0),2)
plt.figure(figsize = (10,10))
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
mask_copy = cv2.cvtColor(mask_copy, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(mask)
plt.subplot(1,2,2)
plt.imshow(mask_copy)
plt.show()

# %%
# @title FIXING CAT DETECTION
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalcatface.xml')
kucing_ori = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/kucing.jpg',0)
cat_gray = kucing_ori.copy()
roi_wajah = cascade_wajah.detectMultiScale(cat_gray)
for (x,y,w,h) in roi_wajah:
  cv2.rectangle(cat_gray,(x,y),(x+w,y+h),(0,255,0),2)
plt.figure(figsize = (10,10))
kucing_ori = cv2.cvtColor(kucing_ori, cv2.COLOR_BGR2RGB)
cat_gray = cv2.cvtColor(cat_gray, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(kucing_ori)
plt.subplot(1,2,2)
plt.imshow(cat_gray)
plt.show()

# %%
# @title EYES DETECTION
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_eye.xml')
jokowi_ori = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg', 0)
jokowi_copy = jokowi_ori.copy()
roi_wajah = cascade_wajah.detectMultiScale(jokowi_copy)
for (x,y,w,h) in roi_wajah:
  cv2.rectangle(jokowi_copy,(x,y),(x+w,y+h),(255,255,255),2)
plt.figure(figsize = (10,10))
jokowi_ori = cv2.cvtColor(jokowi_ori, cv2.COLOR_BGR2RGB)
jokowi_copy = cv2.cvtColor(jokowi_copy, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(jokowi_ori)
plt.subplot(1,2,2)
plt.imshow(jokowi_copy)
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')
mjordan = cv2.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg', 0)
mjordan_copy = mjordan.copy()
roi_wajah = cascade_wajah.detectMultiScale(mjordan_copy)
for (x,y,w,h) in roi_wajah:
  # cv2.rectangle(mjordan_copy,(x,y),(x+w,y+h),(0,255,0),2)
  face_roi = mjordan_copy[y:y+h,x:x+w]
  blurred_face = cv2.GaussianBlur(face_roi, (25, 25), 4)
  mjordan_copy[y:y + h, x:x + w] = blurred_face

plt.figure(figsize = (10,10))
mjordan = cv2.cvtColor(mjordan, cv2.COLOR_BGR2RGB)
mjordan_copy = cv2.cvtColor(mjordan_copy, cv2.COLOR_BGR2RGB)
plt.subplot(1,2,1)
plt.imshow(mjordan)
plt.subplot(1,2,2)
plt.imshow(mjordan_copy)
plt.show()

# %%
import os


path_plate = "/content/drive/MyDrive/PCVK/KTP_More"
for name_file in sorted(os.listdir(path_plate)):
  src = cv2.imread('/content/drive/MyDrive/PCVK/KTP_More/ktp1.png')
  blurred = src.copy()
  gray = blurred.copy()

for i in range(10):
  blurred = cv2.GaussianBlur(src, (5, 5), 0.5)
gray = cv2.cvtColor(blurred, cv2.COLOR_BGR2GRAY)

# Thresholding Otsu
ret, bw = cv2.threshold(gray.copy(), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
print(ret, bw.shape)
ktp = cv2.cvtColor(src,cv2.COLOR_BGR2RGB)
# ori
plt.imshow(ktp)
plt.title("Original Image")
plt.axis("off")
plt.show()

# Tampilkan gambar grayscale
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# Tampilkan gambar hasil thresholding (biner)
plt.imshow(bw, cmap='gray')
plt.title("Binary Image after Thresholding")
plt.axis("off")
plt.show()
# Out:
# 88.0 (338, 600)

# %%
# Terapkan operasi morfologi (misalnya dilasi atau erosi)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 2))
bw_morph = cv2.morphologyEx(bw, cv2.MORPH_OPEN, kernel)
# bw_morph = cv2.morphologyEx(bw, cv2.MORPH_ERODE, kernel)
# bw_morph = cv2.morphologyEx(bw_morph, cv2.MORPH_ERODE, kernel)

# Tampilkan gambar hasil operasi morfologi
plt.imshow(bw_morph, cmap='gray')
plt.title("Morphological Open Operation")
# plt.axis("off")
plt.show()

# %%
# Pastikan menggunakan gambar biner yang sudah diproses
contours, hierarchy = cv2.findContours(bw_morph, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# Gambar Contour
ktp_ori = src.copy()  # Salin gambar asli untuk menampilkan hasil
for cnt in contours:
    x, y, w, h = cv2.boundingRect(cnt)
    ras = format(w / h, '.2f')

    # Seleksi kontur berdasarkan ukuran dan rasio
    if h >= 15 and w >= 10 and float(ras) <= 1:
        cv2.rectangle(ktp_ori, (x, y), (x + w, y + h), (0, 0, 255), thickness=1)
    elif h <= 30 and w >= 10 :
        cv2.rectangle(ktp_ori, (x, y), (x + w, y + h), (0, 255, 0), thickness=1)

ktp_ori = cv2.cvtColor(ktp_ori, cv2.COLOR_BGR2RGB)
plt.imshow(ktp_ori)
plt.title("Contour Detection")
plt.show()

# %%
y = 50
x = 155
ktp_crop = ktp_ori[y:80, x:400]
plt.imshow(ktp_crop)
plt.title("Cropped Image")
plt.axis("off") # Untuk menyembunyikan sumbu
plt.show()

output_dir_testing = "/content/drive/MyDrive/PCVK/digits/testing"
sample_folder = os.path.join(output_dir_testing, "sample1")
if not os.path.exists(output_dir_testing):
    os.makedirs(output_dir_testing)

if not os.path.exists(sample_folder):
    os.makedirs(sample_folder)

# Menyimpan hasil cropping dengan nama urut digit
output_path = os.path.join(sample_folder, "KTP_cropped.jpg")
ktp_crop_bgr = cv2.cvtColor((ktp_crop * 255).astype('uint8'), cv2.COLOR_RGB2BGR)

# Menyimpan gambar ke direktori testing
cv2.imwrite(output_path, ktp_crop_bgr)

print(f"Gambar hasil crop berhasil disimpan di: {output_path}")
# Out:
# Gambar hasil crop berhasil disimpan di: /content/drive/MyDrive/PCVK/digits/testing/sample1/KTP_cropped.jpg

# %%
import os
from tqdm import tqdm
import cv2
import random
import numpy as np
import pickle

# Direktori data training
DATADIR = "/content/drive/MyDrive/PCVK/digits/training"
dirs = []

training_data = []
width, height = 100, 100

# Looping direktori data training untuk diambil nama karakternya
for char_name in sorted(os.listdir(DATADIR)):
    dirs.append(char_name)

# Looping semua image data training untuk diubah menjadi array
for char_name in dirs:
    path = os.path.join(DATADIR, char_name)
    class_number = dirs.index(char_name)
    for img in tqdm(os.listdir(path)):
        try:
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_ANYCOLOR)
            new_array = cv2.resize(img_array, (width, height))
            training_data.append([new_array, class_number])
        except Exception as e:
            pass

random.shuffle(training_data)
X = []
Y = []

for feature, label in training_data:
    X.append(feature)
    Y.append(label)

X = np.array(X).reshape(-1, width, height, 1)

# Tulis ke file pickle
pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("Y.pickle", "wb")
pickle.dump(Y, pickle_out)
pickle_out.close()
# Out:
# ...
# 100%|██████████| 91/91 [00:21<00:00,  4.28it/s]

# %%
import pickle
import keras
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D
from keras.models import Model
from keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Load file pickle
pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

pickle_in = open("Y.pickle", "rb")
Y = pickle.load(pickle_in)
# adds
# Check and adjust data cardinality
num_samples = min(len(X), len(Y))  # Take the minimum number of samples
X = X[:num_samples] # Slice X to match num_samples
Y = Y[:num_samples] # Slice Y to match num_samples

# Y = to_categorical(Y)
Y = to_categorical(Y, num_classes=34)
X = X / 255.0
width, height = 100, 100

# Input layer
inputs = Input(shape=(width, height, 1))
conv_layer = ZeroPadding2D(padding=(2, 2))(inputs)
conv_layer = Conv2D(16, (5, 5), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = Conv2D(32, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)
conv_layer = MaxPooling2D((2, 2))(conv_layer)
conv_layer = Conv2D(64, (3, 3), strides=(1, 1),
activation='relu')(conv_layer)

flaten = Flatten()(conv_layer)

fc_layer = Dense(256, activation='relu')(flaten)
fc_layer = Dense(64, activation='relu')(fc_layer)

# Output layer
outputs = Dense(34, activation='softmax')(fc_layer)

adam = Adam(learning_rate=0.0001)
model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=adam, loss='categorical_crossentropy',
metrics=['accuracy'])

model.fit(X, Y, epochs=20, verbose=1)

model.save('anpr.keras')
# Out:
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 22s 740ms/step - accuracy: 0.0774 - loss: 3.2646
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 563ms/step - accuracy: 0.0964 - loss: 2.9419
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 559ms/step - accuracy: 0.1098 - loss: 2.8192
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 14s 536ms/step - accuracy: 0.0980 - loss: 2.5696
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 535ms/step - accuracy: 0.0986 - loss: 2.4085
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 563ms/step - accuracy: 0.1243 - loss: 2.3725
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 549ms/step - accuracy: 0.0965 - loss: 2.4162
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 566ms/step - accuracy: 0.0927 - loss: 2.3747
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 16s 577ms/step - accuracy: 0.0901 - loss: 2.3408
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 533ms/step - accuracy: 0.0987 - loss: 2.3413
# Epoch 11/20
# ...

# %%
import os
import cv2
import tensorflow as tf
import numpy as np

data_dir_training = "/content/drive/MyDrive/PCVK/digits/training"
data_dir_testing = "/content/drive/MyDrive/PCVK/digits/testing"

dirs = []
width, height = 100, 100

model = tf.keras.models.load_model("anpr.keras")

for char_name in sorted(os.listdir(data_dir_training)):
    dirs.append(char_name)

for car in sorted(os.listdir(data_dir_testing)):
    temp = ""
    for char_img in sorted(os.listdir(os.path.join(data_dir_testing,
car))):
        img_array = cv2.imread(os.path.join(data_dir_testing, car,
char_img), cv2.IMREAD_ANYCOLOR)
        new_array = cv2.resize(img_array, (width, height))
        new_array = np.array(new_array).reshape(-1, width, height,
1)

        new_array = new_array / 255.0

        prediction = model.predict(new_array)
        temp += dirs[np.argmax(prediction[0])]

    print("folder name: {} no: {}".format(car, temp))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# folder name: sample1 no: 77777777777

# %%
import cv2
import os
import numpy as np

# Direktori untuk menyimpan hasil cropping testing
output_dir_testing = "/content/drive/MyDrive/PCVK/digits/testing"

# Membuat folder untuk setiap testing (contoh nama folder "sample1")
sample_folder = os.path.join(output_dir_testing, "sample1")
if not os.path.exists(sample_folder):
    os.makedirs(sample_folder)

# Mengubah gambar dari plt menjadi format cv2 jika diperlukan
if np.max(ktp_crop) <= 1:  # Jika gambar dalam range 0-1, ubah ke 0-255
    ktp_crop = (ktp_crop * 255).astype('uint8')

# Pastikan gambar dalam format BGR untuk OpenCV
if ktp_crop.shape[-1] == 3:  # Jika gambar RGB, ubah ke BGR
    ktp_crop = cv2.cvtColor(ktp_crop, cv2.COLOR_RGB2BGR)

# Parameter koordinat cropping untuk tiap digit (disesuaikan dengan NIK)
digit_height = 30  # Ketinggian crop digit (sesuaikan)
digit_width = 20   # Lebar crop digit (sesuaikan)
start_y = 0        # Y awal relatif pada `ktp_crop` (karena sudah dicrop dari KTP asli)
start_x = 0        # X awal relatif pada `ktp_crop`

# Looping untuk 16 digit dari NIK
for i in range(16):
    # Menghitung koordinat cropping
    x = start_x + i * (digit_width + 5)  # Sesuaikan jarak antar digit (gap = 5)
    y = start_y

    # Melakukan crop digit
    cropped_digit = ktp_crop[y:y + digit_height, x:x + digit_width]

    # Menyimpan hasil cropping dengan nama urut digit
    output_path = os.path.join(sample_folder, f"digit_{i}.jpg")
    # cv2.imwrite(output_path, cropped_digit)

print("Cropping selesai dan gambar disimpan di folder testing sample1.")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-80-ff866cb5bf0a> in <cell line: 28>()
#      36     # Menyimpan hasil cropping dengan nama urut digit
#      37     output_path = os.path.join(sample_folder, f"digit_{i}.jpg")
# ---> 38     cv2.imwrite(output_path, cropped_digit)
#      39
#      40 print("Cropping selesai dan gambar disimpan di folder testing sample1.")
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
