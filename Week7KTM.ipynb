# %% [markdown]
# <a href="https://colab.research.google.com/github/Muzzarino2811/20_MuzzarinoAkbar/blob/main/Week7KTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
img_path = '/content/drive/MyDrive/PCVK/Images/UTSPCVK.jpg'
image = cv2.imread(img_path)

# Convert to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Gamma Correction
gamma = 0.2
invGamma = 1.0 / gamma
table = np.array([((i / 255.0) ** invGamma) * 255 for i in range(256)], dtype="uint8")
image_gamma_corrected = cv2.LUT(image_rgb, table)

# Denoising
image_gamma_corrected = cv2.fastNlMeansDenoisingColored(image_gamma_corrected, None, 15, 15, 7, 25)

# Kontras and Brightness
alpha, beta = 0.9, 21
image_enhanced = cv2.convertScaleAbs(image_gamma_corrected, alpha=alpha, beta=beta)

# Display images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_enhanced)
plt.title('Enhanced Image')
plt.axis('off')

plt.show()
