# %% [markdown]
# <a href="https://colab.research.google.com/github/Muzzarino2811/20_MuzzarinoAkbar/blob/main/Week1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Cat03.jpg/800px-Cat03.jpg"]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                           #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)  #resize image to half size
  image_2 = cv.cvtColor (image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                          #show image
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = " ,tinggi," x ", lebar )
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  400  x  400
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#membuat garis horizonal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
#Pertanyaan

#1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# Karena menggunakan google colab yang sudah terintegrasi dengan backend python di database google  akan membuat mengerjakan tugas python lebih mudah dan hasilnya bisa langsung terlihat

#2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# Numpy berfungsi untuk komputasi matematika di python
# pandas berfungsi untuk manipulasi dan analisis data
# cv2 berfungsi untuk pemrosesan gambar dan video
# cv2_imshow berfungsi untuk menampilkan gambar menggunakan open cv
# skimage io berfungsi untuk membaca dan menulis gambar dari format url
# skimage transform berfungsi untuk mengubah bentuk dan ukuran gambar
# PIL berfungsi untuk membuka,memanipulasi, dan menyimpan berbagai format gambar
# matplotlib.pylab berfungsi untuk menyediakan interface visualisasi grafik

#tidak semua library terpakai di sesi ini,hanya beberapa seperti cv

#3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut "image = cv.resize(image, (0,0), fx=0.5, fy=0.5)" Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# Itu adalah kode untuk resize gambar, jika tidak dilakukan gambar akan tetap pada ukuran asilnya yang mungkin saja bisa menyulitkan visualisasi garis

#4. Perhatikan potongan kode progam berikut : "#membuat garis horizonal ditengah image for y in range (lebar): image_3[int((tinggi)/2),y] = [255,255,255]"
#Apakah kegunaan kode [255,255,255] ? Jelaskan!
# [255,255,255] adalah kode biner yang mewakili warna putih sehingga garis yang muncul berwarna putih

#5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#Semakin rendah resolusi gambar maka gambar memiliki lebih sedikit pixel,sehingga gambar tidak terlalu detail dan mungkin terlihat kotak kotak pixelnya
#Semakin tinggi resolusi gambar maka gambar memiliki lebih banyak pixel, sehingga gambar terlihat akan lebih sangat detail dan lebih jernih

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


tinggi, lebar, _ = image.shape

# Menggambar garis silang "X"
cv.line(image_3, (0, 0), (lebar, tinggi), (255, 255, 255), 1)
cv.line(image_3, (lebar, 0), (0, tinggi), (255, 255, 255), 1)
final_frame = cv.hconcat((image_2, image_3))


cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)



# Menggambar garis lurus ditengah
cv.line(image_3, (50, int (tinggi/2)), (100, int (tinggi/2)), (255, 255, 255), 1)
final_frame = cv.hconcat((image_2, image_3))


cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.rectangle(image_3, (int(lebar/2)-20, int(tinggi/2)-20), (int(lebar/2)+20, int(tinggi/2)+20), [255,255,255],-1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>
